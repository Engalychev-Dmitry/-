# %% [markdown]
# ФИО

# %%
print('Енгалычев Дмитрий Алекандрович')
# Out:
# Енгалычев Дмитрий Алекандрович

# %% [markdown]
# **Во всей практике нельзя применять библиотеки предоставляющие готовые решения!**

# %% [markdown]
# # **Задача 1.**

# %% [markdown]
# Типы данных Напишите программу на Python, которая принимает список чисел в качестве входных данных от пользователя, а затем выводит сумму, среднее значение и максимальное значение из списка.
#
# Дано:
# ```
# 1 2 3 4 5 6 7
# ```
# Вывод:
#
# ```
# Сумма чисел: 28
# Среднее арифм.: 4.0
# Максимальное значение: 7
# ```

# %%
list = []
n = int(input('Введите количество чисел: '))
for a in range(0,int(n)):
  list.append(int(input()))
sum = 0
for a in list:
  sum += a
arifm = sum / n
max = -1
for a in list:
  if a > max:
    max = a





print('Сумма чисел: ' + str((sum)))
print('Среднее арифм.: ' + str((arifm) ))
print('Максимальное значение: ' + str((max)))
# Out:
# Введите количество чисел: 3
# 12
# 7
# 2
# Сумма чисел: 21
# Среднее арифм.: 7.0
# Максимальное значение: 12

# %% [markdown]
# # **Задача 2.**

# %% [markdown]
# Напишите программу на Python, которая принимает список слов в качестве входных данных от пользователя, а затем распечатывает список в обратном порядке.
#
# Ввод:
#
# ```
# апельсин мандарин яблоко
# ```
#
# Вывод:
#
# ```
# яблоко мандарин апельсин
# ```

# %%
list = []
list1 = []
n = int(input('Введите количество слов: '))
for a in range(0,n):
  list.append(input('Введите одно слово: '))
for a in list[::-1]:
  list1.append(a)
print(list1)
# Out:
# Введите количество слов: 3
# Введите одно слово: gfgf
# Введите одно слово: vfvf
# Введите одно слово: lzlz
# ['lzlz', 'vfvf', 'gfgf']

# %% [markdown]
# # **Задача 3**

# %% [markdown]
# Простой чат-бот
# Создайте простого чат-бота, который отвечает на основные запросы пользователей. Программа должна использовать условные выражения для определения намерений пользователя и последующего соответствующего ответа.
#
# Чат бот может:
#
# - помогать складывать числа
# - подсказывать фильм, музыку и тд (из заранее созданного списка)
# - создавать список дел (а также выводить его, обновлять, очищать)
#
# Интерфейс чат-бота на ваше усмотрение, это могут быть как заранее определенные команды, так и к примеру вызов команды по номеру
#
# *Реализовать без использования функций*
#
# Пример:
#
# Ввод:
#
# ```
# Олег, какую мызыку посоветуешь?
# ```
#
# Вывод:
#
# ```
# Я бы посоветовал вам: Led Zeppelin Stairway to Heaven
# ```

# %%
from random import choice
print('Я чат-бот. Вот что я могу: ' +
'  1.складывать числа' +
'  2.подсказать фильм' +
'  3.создать список дел')

n = int(input('Введите номер нужной команды:'))
if n == 1:
 list = []
 n = int(input('Введите количество чисел: '))
 for a in range(0,int(n)):
  list.append(int(input()))
 sum = 0
 for a in list:
   sum += a
 print(sum)
if n == 2:
  musik = ['Егор Шкред - Але', 'иксиксикстентасьён - парадигма']
  film = ['Джуманджи', 'Форсаж']
  g = input('Подсказать музыку или фильм?  -')
  if g == 'музыку':
    print('Я бы посоветовал вам: ' + str(choice(musik)))
  else:
    print('Я бы посоветовал вам: ' + str(choise(film)))
if n == 3:
  j = input('Список дел пуст?(Да или Нет)  -')
  if j == 'Да':
    spisok = []
    print('Что вы хотите сделать?           1) обновить список дел         2)очистить список дел')
    h = int(input('Введите номер нужной команды: '))
    if h == 1:
     spisok.append(input())
    if h == 2:
     spisok = []

  else:
   print('Что вы хотите сделать?          1)вывести список дел     2) обновить список дел         3)очистить список дел')
   h = int(input('Введите номер нужной команды: '))
   if h == 1:
    print(spisok)
   if h == 2:
    spisok.append(input())
   if h == 3:
    spisok = []
# Out:
# Я чат-бот. Вот что я могу:   1.складывать числа  2.подсказать фильм  3.создать список дел
# Введите номер нужной команды:3
# Список дел пуст?(Да или Нет)  -Нет
# Что вы хотите сделать?          1)вывести список дел     2) обновить список дел         3)очистить список дел
# Введите номер нужной команды: 3

# %% [markdown]
# # **Задача 4.**

# %% [markdown]
# Камень, ножницы, бумага
#
# Создайте игру в Камень, ножницы, бумагу, в которой пользователь может играть против компьютера. Программа должна запросить выбор пользователя, а затем сгенерировать выбор компьютера. Затем программа должна определить победителя на основе правил игры.
#
# **Этап 1:**
#
# Определение победителя
#
# **Этап 2:**
#
# Игра до 3 побед
#
#
# Вввод для "Этап 1":
#
# ```
# Камень
# ```
#
# Вывод:
#
# ```
# Компьютер: Ножницы
# Игрок: Камень
# Победа: Игрок
# ```

# %%
from random import choice
igrok = 0
comp = 0
list = ['камень', 'ножницы','бумага']

while igrok < 3 and comp < 3:
   i = input('Игрок: ')
   k = choice(list)
   print("Компьютер:" + str(k[0:]))
   if i == 'камень'and k == "камень":
    igrok += 0
    print('Ничья')
   if i == 'камень'and k == "ножницы":
    igrok += 1
    print('Победа : Игрок')
   if i == 'камень'and k == 'бумага':
    comp += 1
    print('Победа : Компьютер')
   if i == 'ножницы' and k == 'камень':
    comp += 1
    print('Победа : Компьютер')
   if i == 'ножницы' and k == 'ножницы':
    comp += 0
    print('Ничья')
   if i == 'ножницы' and k == 'бумага':
    igrok += 1
    print('Победа : Игрок')
   if i == 'бумага' and k == 'камень':
    igrok += 1
    print('Победа : Игрок')
   if i == 'бумага' and k == 'ножницы':
    comp += 1
    print('Победа : Компьютер')
   if i == 'бумага' and k == 'бумага':
    comp += 0
    print('Ничья')
if igrok == 3:
  print('ИГРОК ПОБЕДИЛ!')
else:
  print('КОМПЮТЕР ПОБЕДИЛ!')
# Out:
# Игрок: камень
# Компьютер:бумага
# Победа : Компьютер
# Игрок: камень
# Компьютер:камень
# Ничья
# Игрок: камень
# Компьютер:ножницы
# Победа : Игрок
# Игрок: камень
# Компьютер:бумага
# Победа : Компьютер
# Игрок: камень
# Компьютер:камень
# Ничья
# Игрок: камень
# Компьютер:камень
# Ничья
# Игрок: камень
# Компьютер:ножницы
# Победа : Игрок
# Игрок: камень
# Компьютер:бумага
# Победа : Компьютер
# КОМПЮТЕР ПОБЕДИЛ!

# %% [markdown]
# # **Задача 6.**

# %% [markdown]
# Создайте игру "Палач" или "Виселица", в которой пользователь должен угадать слово, предлагая буквы. Программа должна выбрать случайное слово, а затем разрешить пользователю угадывать буквы. После каждого угадывания программа должна сообщать пользователю, есть ли в слове буква или нет.
#
# **Этап 1**
# Создать саму игру
#
# **Этап 2:**
# Ввести подсчет количества очков и ограничения на попытки

# %%
from random import choice
slovo = ['мандарин','слон','челядь','перевёртыш']
c = 0
v=0
h =0
g = choice(slovo)
print(g)
while 5-c != 0:
 buk =  input('Введите букву: ')
 if buk == g:
  print('Очки :' + str(len(g)) )
  break
 v = 0
 for a in g:
   if a == buk:
      v += 1
 if v >=  1:
      h += v
      print(h)
      print("Вы угадали букву!")
      print(v)
 else:
      c += 1
      print('Вы не угадали букву. У вас осталось ' + str(5- c) + ' попыток')
 if int(len(g)) == int(h):
  print('очков ' + str(h))
  break

if 5-c == 0:
       print('Вы проиграли')

print('вы угадали слово!')
# Единственное что не знаю , это как запоминать предыдущие буквы , чтобы при повторном вводе они не считались повторно. ( помню что  через функцию, но конкретно в этом коде не знаю куда что запихнуть)
# Out:
# челядь
# Введите букву: челядь
# Очки :6
# вы угадали слово!

# %% [markdown]
# # **Задача 7.**

# %% [markdown]
# **Цифра на определенном месте:**
#
# Последовательно записан натуральный ряд чисел.
#
# Какая цифра стоит в N позиции
#
#
# Вввод:
#
# ```
# Введите номер позиции: 1234567890
# ```
#
# Вывод:
#
# ```
# 8
# ```
